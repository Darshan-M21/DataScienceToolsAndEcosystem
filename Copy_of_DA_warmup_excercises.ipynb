# %% [markdown]
# <a href="https://colab.research.google.com/github/Darshan-M21/DataScienceToolsAndEcosystem/blob/main/Copy_of_DA_warmup_excercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dict1 = {'Name':['Priyang','Aradhya','Krishna','Vedant','Parshiv','Mittal','Archana'],
         'Marks':[98,89,99,87,90,83,99],
         "Gender":["Male",'Female','Male','Male','Male','Male','Female']}
df1 = pd.DataFrame(dict1)
df1
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1  Aradhya     89  Female
# 2  Krishna     99    Male
# 3   Vedant     87    Male
# 4  Parshiv     90    Male
# 5   Mittal     83    Male
# 6  Archana     99  Female

# %% [markdown]
# 1.DIsplay top 3 rows of dataset - head

# %%
df1.head(3)
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1  Aradhya     89  Female
# 2  Krishna     99    Male

# %% [markdown]
# 2. Display last 2 rows from the bottom - tail

# %%
df1.tail(2)
# Out:
#       Name  Marks  Gender
# 5   Mittal     83    Male
# 6  Archana     99  Female

# %% [markdown]
# 3.Find the shape of our data set(number of rows and no. of col's) - shape

# %%
print(type(df1.shape))
df1.shape
# Out:
# <class 'tuple'>
# (7, 3)

# %%
print('Rows = ',df1.shape[0],'Col = ',df1.shape[1])
# Out:
# Rows =  7 Col =  3

# %% [markdown]
# 4. Get info abt our dataset like total number of rows, col,datatypes of each and memory req.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   7 non-null      int64
#  2   Gender  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# 5. Check null values in the dataset

# %%
df1.isnull().sum(axis = 0)# axis = 1 --->> Display it row-wise
# Out:
# Name      0
# Marks     0
# Gender    0
# dtype: int64

# %% [markdown]
# 6. Get overall stats abt the dataframe - for numerical col only

# %%
df1.describe(include = 'all')
# Out:
#            Name      Marks Gender
# count         7   7.000000      7
# unique        7        NaN      2
# top     Priyang        NaN   Male
# freq          1        NaN      5
# mean        NaN  92.142857    NaN
# std         NaN   6.491753    NaN
# min         NaN  83.000000    NaN
# 25%         NaN  88.000000    NaN
# 50%         NaN  90.000000    NaN
# 75%         NaN  98.500000    NaN
# max         NaN  99.000000    NaN

# %% [markdown]
# 7. Find unique elements from gender col

# %%
df1[]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1  Aradhya     89  Female
# 2  Krishna     99    Male
# 3   Vedant     87    Male
# 4  Parshiv     90    Male
# 5   Mittal     83    Male
# 6  Archana     99  Female

# %%
df1['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# 8. FInd the no. of unique values from the gender col - nunique() - method

# %%
df1['Gender'].nunique()
# Out:
# 2

# %% [markdown]
# 9. Display count of unique values in the Gender col

# %%
df1['Gender'].value_counts()
# Out:
# Male      5
# Female    2
# Name: Gender, dtype: int64

# %% [markdown]
# 10. Find the total number of students having marks bw 90 to 100 using bw method(inclusive)

# %%
df1['Marks']
# Out:
# 0    98
# 1    89
# 2    99
# 3    87
# 4    90
# 5    83
# 6    99
# Name: Marks, dtype: int64

# %%
df1['Marks']>=90
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# Name: Marks, dtype: bool

# %%
df1[df1['Marks']>=90]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 2  Krishna     99    Male
# 4  Parshiv     90    Male
# 6  Archana     99  Female

# %%
(df1['Marks']>=90)  &  (df1['Marks']<=100)
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# Name: Marks, dtype: bool

# %%
df1[(df1['Marks']>=90)  &  (df1['Marks']<=100)]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 2  Krishna     99    Male
# 4  Parshiv     90    Male
# 6  Archana     99  Female

# %%
tot = len(df1[(df1['Marks']>=90)  &  (df1['Marks']<=100)])
print('Total = ',tot)
# Out:
# Total =  4

# %%
df1['Marks'].between(90,100) # both values are inclusive
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# Name: Marks, dtype: bool

# %%
sum(df1['Marks'].between(90,100))
# Out:
# 4

# %% [markdown]
# 11. Find average marks

# %%
df1['Marks'].mean() # min() , max()
# Out:
# 92.14285714285714

# %% [markdown]
# 12. Apply method

# %%
def marks(x):
    return x//2

# %%
marks(df1['Marks'])
# Out:
# 0    49
# 1    44
# 2    49
# 3    43
# 4    45
# 5    41
# 6    49
# Name: Marks, dtype: int64

# %%
df1['Half marks'] = df1['Marks'].apply(marks)
df1
# Out:
#       Name  Marks  Gender  Half marks
# 0  Priyang     98    Male          49
# 1  Aradhya     89  Female          44
# 2  Krishna     99    Male          49
# 3   Vedant     87    Male          43
# 4  Parshiv     90    Male          45
# 5   Mittal     83    Male          41
# 6  Archana     99  Female          49

# %%
df1['Marks'].apply(lambda x:x/2)
# Out:
# 0    49.0
# 1    44.5
# 2    49.5
# 3    43.5
# 4    45.0
# 5    41.5
# 6    49.5
# Name: Marks, dtype: float64

# %%
df1['Name'].apply(len) # length of strings
# Out:
# 0    7
# 1    7
# 2    7
# 3    6
# 4    7
# 5    6
# 6    7
# Name: Name, dtype: int64

# %% [markdown]
# 13. Map Function

# %%
df1
# Out:
#       Name  Marks  Gender  Half marks
# 0  Priyang     98    Male          49
# 1  Aradhya     89  Female          44
# 2  Krishna     99    Male          49
# 3   Vedant     87    Male          43
# 4  Parshiv     90    Male          45
# 5   Mittal     83    Male          41
# 6  Archana     99  Female          49

# %%
df1['Male_Female'] = df1['Gender'].map({'Male':1,'Female':0})

# %%
df1
# Out:
#       Name  Marks  Gender  Half marks  Male_Female
# 0  Priyang     98    Male          49            1
# 1  Aradhya     89  Female          44            0
# 2  Krishna     99    Male          49            1
# 3   Vedant     87    Male          43            1
# 4  Parshiv     90    Male          45            1
# 5   Mittal     83    Male          41            1
# 6  Archana     99  Female          49            0

# %% [markdown]
# 14. Drop the cols

# %%
df1.drop('Male_Female',axis = 1)
# Out:
#       Name  Marks  Gender  Half marks
# 0  Priyang     98    Male          49
# 1  Aradhya     89  Female          44
# 2  Krishna     99    Male          49
# 3   Vedant     87    Male          43
# 4  Parshiv     90    Male          45
# 5   Mittal     83    Male          41
# 6  Archana     99  Female          49

# %%
df1.drop(['Male_Female','Half marks'],axis = 1,inplace = True)

# %%
df1
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1  Aradhya     89  Female
# 2  Krishna     99    Male
# 3   Vedant     87    Male
# 4  Parshiv     90    Male
# 5   Mittal     83    Male
# 6  Archana     99  Female

# %% [markdown]
# 15. Print name of the col's

# %%
df1.columns
# Out:
# Index(['Name', 'Marks', 'Gender'], dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# 16. Sort the dataframe acc to marks col

# %%
df1.sort_values(by = 'Marks')
# Out:
#       Name  Marks  Gender
# 5   Mittal     83    Male
# 3   Vedant     87    Male
# 1  Aradhya     89  Female
# 4  Parshiv     90    Male
# 0  Priyang     98    Male
# 2  Krishna     99    Male
# 6  Archana     99  Female

# %%
df1.sort_values(by = 'Marks',ascending = False)
# Out:
#       Name  Marks  Gender
# 2  Krishna     99    Male
# 6  Archana     99  Female
# 0  Priyang     98    Male
# 4  Parshiv     90    Male
# 1  Aradhya     89  Female
# 3   Vedant     87    Male
# 5   Mittal     83    Male

# %%
df1.sort_values(by = ['Marks','Gender'],ascending = False)
# Out:
#       Name  Marks  Gender
# 2  Krishna     99    Male
# 6  Archana     99  Female
# 0  Priyang     98    Male
# 4  Parshiv     90    Male
# 1  Aradhya     89  Female
# 3   Vedant     87    Male
# 5   Mittal     83    Male

# %% [markdown]
# 17. Print the name and marks of the female students only

# %%
df1['Gender'] =='Female'
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# Name: Gender, dtype: bool

# %%
df1[df1['Gender'] =='Female']
# Out:
#       Name  Marks  Gender
# 1  Aradhya     89  Female
# 6  Archana     99  Female

# %%
df1[df1['Gender'] =='Female'][['Name','Marks']]
# Out:
#       Name  Marks
# 1  Aradhya     89
# 6  Archana     99

# %%
df1['Gender'].isin(['Female'])
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# Name: Gender, dtype: bool

# %%
df1[df1['Gender'].isin(['Female'])]
# Out:
#       Name  Marks  Gender
# 1  Aradhya     89  Female
# 6  Archana     99  Female

# %%
df1[df1['Gender'].isin(['Female'])][['Name','Marks']]
# Out:
#       Name  Marks
# 1  Aradhya     89
# 6  Archana     99
